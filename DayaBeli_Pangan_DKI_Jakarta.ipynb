# %% [markdown]
# <a href="https://colab.research.google.com/github/septianapraditama-dev/Daya-Beli/blob/development/DayaBeli_Pangan_DKI_Jakarta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PreProcessing data UMP DKI Jakarta

# %% [markdown]
# > Inisialisasi & Mounting Drive

# %%
import pandas as pd
import calendar
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Konfigurasi Path (Sesuaikan dengan folder tim DB10-G005)
PATH_FOLDER = '/content/drive/MyDrive/'
FILE_INPUT  = PATH_FOLDER + 'Dataset UMP Indonesia/1704427855898_UMP%202024.xlsx'
FILE_OUTPUT = PATH_FOLDER + 'Capstone/ump_dki_jakarta_daily_clean.csv'

# 3. Parameter Input
REGIONS = ['Jakarta Barat', 'Jakarta Pusat', 'Jakarta Selatan', 'Jakarta Timur', 'Jakarta Utara']
UMP_ANNUAL = {
    2024: 5067381.0,
    2025: 5396761.0
}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# > Fungsi Core Processing (Transformasi)

# %%
# Jalankan pembuatan data
df_ump = generate_ump_data()

# A. FORMAT OUTPUT (Sesuai Spesifikasi)
df_ump['tanggal'] = pd.to_datetime(df_ump['tanggal'])
df_ump['region'] = df_ump['region'].astype('string')
df_ump['ump_daily'] = df_ump['ump_daily'].astype('float64')
df_ump['ump'] = df_ump['ump'].astype('float64')

# URUTKAN BERDASARKAN REGION DULU, LALU TANGGAL
df_ump = df_ump.sort_values(by=['region', 'tanggal']).reset_index(drop=True)

# Simpan ke CSV
df_ump.to_csv(FILE_OUTPUT, index=False)

# %% [markdown]
# > Formating & Ekspor

# %%
# Jalankan pembuatan data
df_ump = generate_ump_clean()

# A. FORMAT OUTPUT (Sesuai Spesifikasi)
df_ump['tanggal'] = pd.to_datetime(df_ump['tanggal'])
df_ump['region'] = df_ump['region'].astype('string')
df_ump['ump_daily'] = df_ump['ump_daily'].astype('float64')
df_ump['ump'] = df_ump['ump'].astype('float64')

# Urutkan berdasarkan waktu (Awal 2024 -> Akhir 2025) baru wilayah
df_ump = df_ump.sort_values(by=['tanggal', 'region']).reset_index(drop=True)

# Simpan ke CSV (Tampilan seperti image_b55d23.png)
df_ump.to_csv(FILE_OUTPUT, index=False)

# %% [markdown]
# > Verifikasi & Preview

# %%
# 1. Cek Shape (731 hari x 5 wilayah = 3.655 baris)
print(f"Total Baris: {len(df_ump)}")

# 2. Preview Data: Harusnya muncul blok Jakarta Barat dulu dari Jan 2024
print("\nPreview Blok Pertama (Jakarta Barat):")
display(df_ump.head(10))

# 3. Preview Perpindahan Region (Melihat transisi antar wilayah)
print("\nPreview Tengah (Cek Transisi Region):")
display(df_ump.iloc[728:735])
# Out:
# Total Baris: 3655
#
# Preview Blok Pertama (Jakarta Barat):
#      tanggal         region      ump_daily        ump
# 0 2024-01-01  Jakarta Barat  163463.903226  5067381.0
# 1 2024-01-02  Jakarta Barat  163463.903226  5067381.0
# 2 2024-01-03  Jakarta Barat  163463.903226  5067381.0
# 3 2024-01-04  Jakarta Barat  163463.903226  5067381.0
# 4 2024-01-05  Jakarta Barat  163463.903226  5067381.0
# 5 2024-01-06  Jakarta Barat  163463.903226  5067381.0
# 6 2024-01-07  Jakarta Barat  163463.903226  5067381.0
# 7 2024-01-08  Jakarta Barat  163463.903226  5067381.0
# 8 2024-01-09  Jakarta Barat  163463.903226  5067381.0
# 9 2024-01-10  Jakarta Barat  163463.903226  5067381.0
# Preview Tengah (Cek Transisi Region):
#        tanggal         region      ump_daily        ump
# 728 2025-12-29  Jakarta Barat  174089.064516  5396761.0
# 729 2025-12-30  Jakarta Barat  174089.064516  5396761.0
# 730 2025-12-31  Jakarta Barat  174089.064516  5396761.0
# ...
